# %%
import pandas as pd

# %%
df = pd.read_csv('raw_data_Liu.csv')
df.columns
# Out:
# Index(['ID', 'Sex', 'Age', 'Height', 'Weight', 'ColdSens', 'ColdExp', 'Workhr',
#        'Coffeeintake', 'Vote_time', 'therm_sens', 'therm_pref', 'location',
#        'mean.Temperature_60', 'grad.Temperature_60', 'sd.Temperature_60',
#        'mean.Temperature_480', 'grad.Temperature_480', 'sd.Temperature_480',
#        'mean.Humidity_60', 'grad.Humidity_60', 'sd.Humidity_60',
#        'mean.Humidity_480', 'grad.Humidity_480', 'sd.Humidity_480',
#        'mean.Winvel_60', 'grad.Winvel_60', 'sd.Winvel_60', 'mean.Winvel_480',
#        'grad.Winvel_480', 'sd.Winvel_480', 'mean.Solar_60', 'grad.Solar_60',
#        'sd.Solar_60', 'mean.Solar_480', 'grad.Solar_480', 'sd.Solar_480',
#        'mean.hr_5', 'grad.hr_5', 'sd.hr_5', 'mean.hr_15', 'grad.hr_15',
#        'sd.hr_15', 'mean.hr_60', 'grad.hr_60', 'sd.hr_60', 'mean.WristT_5',
#        'grad.WristT_5', 'sd.WristT_5', 'mean.WristT_15', 'grad.WristT_15',
#        'sd.WristT_15', 'mean.WristT_60', 'grad.WristT_60', 'sd.WristT_60',
# ...

# %%
df_occ1 = df.query("ID == 1")
df_occ2 = df.query("ID == 2")
df_occ3 = df.query("ID == 3")
df_occ4 = df.query("ID == 4")
df_occ5 = df.query("ID == 5")
df_occ6 = df.query("ID == 6")
df_occ7 = df.query("ID == 7")
df_occ8 = df.query("ID == 8")
df_occ9 = df.query("ID == 9")
df_occ10 = df.query("ID == 10")
df_occ11 = df.query("ID == 11")
df_occ12 = df.query("ID == 12")
df_occ13 = df.query("ID == 13")
df_occ14 = df.query("ID == 14")

# %%
df_occ1_env = df_occ1.filter(['mean.Temperature_60', 'grad.Temperature_60', 'sd.Temperature_60', 'mean.Temperature_480', 'grad.Temperature_480', 'sd.Temperature_480',
                         'mean.Humidity_60', 'grad.Humidity_60', 'sd.Humidity_60', 'mean.Humidity_480', 'grad.Humidity_480', 'sd.Humidity_480',
                         'mean.Winvel_60', 'grad.Winvel_60', 'sd.Winvel_60', 'mean.Winvel_480','grad.Winvel_480', 'sd.Winvel_480', 
                         'mean.Solar_60', 'grad.Solar_60', 'sd.Solar_60', 'mean.Solar_480', 'grad.Solar_480', 'sd.Solar_480'])

df_occ2_env = df_occ2.filter(['mean.Temperature_60', 'grad.Temperature_60', 'sd.Temperature_60', 'mean.Temperature_480', 'grad.Temperature_480', 'sd.Temperature_480',
                         'mean.Humidity_60', 'grad.Humidity_60', 'sd.Humidity_60', 'mean.Humidity_480', 'grad.Humidity_480', 'sd.Humidity_480',
                         'mean.Winvel_60', 'grad.Winvel_60', 'sd.Winvel_60', 'mean.Winvel_480','grad.Winvel_480', 'sd.Winvel_480', 
                         'mean.Solar_60', 'grad.Solar_60', 'sd.Solar_60', 'mean.Solar_480', 'grad.Solar_480', 'sd.Solar_480'])

df_occ3_env = df_occ3.filter(['mean.Temperature_60', 'grad.Temperature_60', 'sd.Temperature_60', 'mean.Temperature_480', 'grad.Temperature_480', 'sd.Temperature_480',
                         'mean.Humidity_60', 'grad.Humidity_60', 'sd.Humidity_60', 'mean.Humidity_480', 'grad.Humidity_480', 'sd.Humidity_480',
                         'mean.Winvel_60', 'grad.Winvel_60', 'sd.Winvel_60', 'mean.Winvel_480','grad.Winvel_480', 'sd.Winvel_480', 
                         'mean.Solar_60', 'grad.Solar_60', 'sd.Solar_60', 'mean.Solar_480', 'grad.Solar_480', 'sd.Solar_480'])

df_occ4_env = df_occ4.filter(['mean.Temperature_60', 'grad.Temperature_60', 'sd.Temperature_60', 'mean.Temperature_480', 'grad.Temperature_480', 'sd.Temperature_480',
                         'mean.Humidity_60', 'grad.Humidity_60', 'sd.Humidity_60', 'mean.Humidity_480', 'grad.Humidity_480', 'sd.Humidity_480',
                         'mean.Winvel_60', 'grad.Winvel_60', 'sd.Winvel_60', 'mean.Winvel_480','grad.Winvel_480', 'sd.Winvel_480', 
                         'mean.Solar_60', 'grad.Solar_60', 'sd.Solar_60', 'mean.Solar_480', 'grad.Solar_480', 'sd.Solar_480'])

df_occ5_env = df_occ5.filter(['mean.Temperature_60', 'grad.Temperature_60', 'sd.Temperature_60', 'mean.Temperature_480', 'grad.Temperature_480', 'sd.Temperature_480',
                         'mean.Humidity_60', 'grad.Humidity_60', 'sd.Humidity_60', 'mean.Humidity_480', 'grad.Humidity_480', 'sd.Humidity_480',
                         'mean.Winvel_60', 'grad.Winvel_60', 'sd.Winvel_60', 'mean.Winvel_480','grad.Winvel_480', 'sd.Winvel_480', 
                         'mean.Solar_60', 'grad.Solar_60', 'sd.Solar_60', 'mean.Solar_480', 'grad.Solar_480', 'sd.Solar_480'])

df_occ6_env = df_occ6.filter(['mean.Temperature_60', 'grad.Temperature_60', 'sd.Temperature_60', 'mean.Temperature_480', 'grad.Temperature_480', 'sd.Temperature_480',
                         'mean.Humidity_60', 'grad.Humidity_60', 'sd.Humidity_60', 'mean.Humidity_480', 'grad.Humidity_480', 'sd.Humidity_480',
                         'mean.Winvel_60', 'grad.Winvel_60', 'sd.Winvel_60', 'mean.Winvel_480','grad.Winvel_480', 'sd.Winvel_480', 
                         'mean.Solar_60', 'grad.Solar_60', 'sd.Solar_60', 'mean.Solar_480', 'grad.Solar_480', 'sd.Solar_480'])

df_occ7_env = df_occ7.filter(['mean.Temperature_60', 'grad.Temperature_60', 'sd.Temperature_60', 'mean.Temperature_480', 'grad.Temperature_480', 'sd.Temperature_480',
                         'mean.Humidity_60', 'grad.Humidity_60', 'sd.Humidity_60', 'mean.Humidity_480', 'grad.Humidity_480', 'sd.Humidity_480',
                         'mean.Winvel_60', 'grad.Winvel_60', 'sd.Winvel_60', 'mean.Winvel_480','grad.Winvel_480', 'sd.Winvel_480', 
                         'mean.Solar_60', 'grad.Solar_60', 'sd.Solar_60', 'mean.Solar_480', 'grad.Solar_480', 'sd.Solar_480'])

df_occ8_env = df_occ8.filter(['mean.Temperature_60', 'grad.Temperature_60', 'sd.Temperature_60', 'mean.Temperature_480', 'grad.Temperature_480', 'sd.Temperature_480',
                         'mean.Humidity_60', 'grad.Humidity_60', 'sd.Humidity_60', 'mean.Humidity_480', 'grad.Humidity_480', 'sd.Humidity_480',
                         'mean.Winvel_60', 'grad.Winvel_60', 'sd.Winvel_60', 'mean.Winvel_480','grad.Winvel_480', 'sd.Winvel_480', 
                         'mean.Solar_60', 'grad.Solar_60', 'sd.Solar_60', 'mean.Solar_480', 'grad.Solar_480', 'sd.Solar_480'])

df_occ9_env = df_occ9.filter(['mean.Temperature_60', 'grad.Temperature_60', 'sd.Temperature_60', 'mean.Temperature_480', 'grad.Temperature_480', 'sd.Temperature_480',
                         'mean.Humidity_60', 'grad.Humidity_60', 'sd.Humidity_60', 'mean.Humidity_480', 'grad.Humidity_480', 'sd.Humidity_480',
                         'mean.Winvel_60', 'grad.Winvel_60', 'sd.Winvel_60', 'mean.Winvel_480','grad.Winvel_480', 'sd.Winvel_480', 
                         'mean.Solar_60', 'grad.Solar_60', 'sd.Solar_60', 'mean.Solar_480', 'grad.Solar_480', 'sd.Solar_480'])

df_occ10_env = df_occ10.filter(['mean.Temperature_60', 'grad.Temperature_60', 'sd.Temperature_60', 'mean.Temperature_480', 'grad.Temperature_480', 'sd.Temperature_480',
                          'mean.Humidity_60', 'grad.Humidity_60', 'sd.Humidity_60', 'mean.Humidity_480', 'grad.Humidity_480', 'sd.Humidity_480',
                          'mean.Winvel_60', 'grad.Winvel_60', 'sd.Winvel_60', 'mean.Winvel_480','grad.Winvel_480', 'sd.Winvel_480', 
                          'mean.Solar_60', 'grad.Solar_60', 'sd.Solar_60', 'mean.Solar_480', 'grad.Solar_480', 'sd.Solar_480'])

df_occ11_env = df_occ11.filter(['mean.Temperature_60', 'grad.Temperature_60', 'sd.Temperature_60', 'mean.Temperature_480', 'grad.Temperature_480', 'sd.Temperature_480',
                          'mean.Humidity_60', 'grad.Humidity_60', 'sd.Humidity_60', 'mean.Humidity_480', 'grad.Humidity_480', 'sd.Humidity_480',
                          'mean.Winvel_60', 'grad.Winvel_60', 'sd.Winvel_60', 'mean.Winvel_480','grad.Winvel_480', 'sd.Winvel_480', 
                          'mean.Solar_60', 'grad.Solar_60', 'sd.Solar_60', 'mean.Solar_480', 'grad.Solar_480', 'sd.Solar_480'])

df_occ12_env = df_occ12.filter(['mean.Temperature_60', 'grad.Temperature_60', 'sd.Temperature_60', 'mean.Temperature_480', 'grad.Temperature_480', 'sd.Temperature_480',
                          'mean.Humidity_60', 'grad.Humidity_60', 'sd.Humidity_60', 'mean.Humidity_480', 'grad.Humidity_480', 'sd.Humidity_480',
                          'mean.Winvel_60', 'grad.Winvel_60', 'sd.Winvel_60', 'mean.Winvel_480','grad.Winvel_480', 'sd.Winvel_480', 
                          'mean.Solar_60', 'grad.Solar_60', 'sd.Solar_60', 'mean.Solar_480', 'grad.Solar_480', 'sd.Solar_480'])

df_occ13_env = df_occ13.filter(['mean.Temperature_60', 'grad.Temperature_60', 'sd.Temperature_60', 'mean.Temperature_480', 'grad.Temperature_480', 'sd.Temperature_480',
                          'mean.Humidity_60', 'grad.Humidity_60', 'sd.Humidity_60', 'mean.Humidity_480', 'grad.Humidity_480', 'sd.Humidity_480',
                          'mean.Winvel_60', 'grad.Winvel_60', 'sd.Winvel_60', 'mean.Winvel_480','grad.Winvel_480', 'sd.Winvel_480', 
                          'mean.Solar_60', 'grad.Solar_60', 'sd.Solar_60', 'mean.Solar_480', 'grad.Solar_480', 'sd.Solar_480'])

df_occ14_env = df_occ14.filter(['mean.Temperature_60', 'grad.Temperature_60', 'sd.Temperature_60', 'mean.Temperature_480', 'grad.Temperature_480', 'sd.Temperature_480',
                          'mean.Humidity_60', 'grad.Humidity_60', 'sd.Humidity_60', 'mean.Humidity_480', 'grad.Humidity_480', 'sd.Humidity_480',
                          'mean.Winvel_60', 'grad.Winvel_60', 'sd.Winvel_60', 'mean.Winvel_480','grad.Winvel_480', 'sd.Winvel_480', 
                          'mean.Solar_60', 'grad.Solar_60', 'sd.Solar_60', 'mean.Solar_480', 'grad.Solar_480', 'sd.Solar_480'])

# %%
df_occ1_phy = df_occ1.filter(['mean.hr_5', 'grad.hr_5', 'sd.hr_5', 'mean.hr_15', 'grad.hr_15','sd.hr_15', 'mean.hr_60', 'grad.hr_60', 'sd.hr_60', 
                         'mean.WristT_5', 'grad.WristT_5', 'sd.WristT_5', 'mean.WristT_15', 'grad.WristT_15', 'sd.WristT_15', 'mean.WristT_60', 'grad.WristT_60', 'sd.WristT_60',
                         'mean.AnkleT_5', 'grad.AnkleT_5', 'sd.AnkleT_5', 'mean.AnkleT_15', 'grad.AnkleT_15', 'sd.AnkleT_15', 'mean.AnkleT_60', 'grad.AnkleT_60','sd.AnkleT_60', 
                         'mean.PantT_5', 'grad.PantT_5', 'sd.PantT_5', 'mean.PantT_15', 'grad.PantT_15', 'sd.PantT_15', 'mean.PantT_60','grad.PantT_60', 'sd.PantT_60', 
                         'mean.act_5', 'grad.act_5', 'sd.act_5','mean.act_15', 'grad.act_15', 'sd.act_15', 'mean.act_60', 'grad.act_60', 'sd.act_60'])

df_occ2_phy = df_occ2.filter(['mean.hr_5', 'grad.hr_5', 'sd.hr_5', 'mean.hr_15', 'grad.hr_15','sd.hr_15', 'mean.hr_60', 'grad.hr_60', 'sd.hr_60', 
                         'mean.WristT_5', 'grad.WristT_5', 'sd.WristT_5', 'mean.WristT_15', 'grad.WristT_15', 'sd.WristT_15', 'mean.WristT_60', 'grad.WristT_60', 'sd.WristT_60',
                         'mean.AnkleT_5', 'grad.AnkleT_5', 'sd.AnkleT_5', 'mean.AnkleT_15', 'grad.AnkleT_15', 'sd.AnkleT_15', 'mean.AnkleT_60', 'grad.AnkleT_60','sd.AnkleT_60', 
                         'mean.PantT_5', 'grad.PantT_5', 'sd.PantT_5', 'mean.PantT_15', 'grad.PantT_15', 'sd.PantT_15', 'mean.PantT_60','grad.PantT_60', 'sd.PantT_60', 
                         'mean.act_5', 'grad.act_5', 'sd.act_5','mean.act_15', 'grad.act_15', 'sd.act_15', 'mean.act_60', 'grad.act_60', 'sd.act_60'])

df_occ3_phy = df_occ3.filter(['mean.hr_5', 'grad.hr_5', 'sd.hr_5', 'mean.hr_15', 'grad.hr_15','sd.hr_15', 'mean.hr_60', 'grad.hr_60', 'sd.hr_60', 
                         'mean.WristT_5', 'grad.WristT_5', 'sd.WristT_5', 'mean.WristT_15', 'grad.WristT_15', 'sd.WristT_15', 'mean.WristT_60', 'grad.WristT_60', 'sd.WristT_60',
                         'mean.AnkleT_5', 'grad.AnkleT_5', 'sd.AnkleT_5', 'mean.AnkleT_15', 'grad.AnkleT_15', 'sd.AnkleT_15', 'mean.AnkleT_60', 'grad.AnkleT_60','sd.AnkleT_60', 
                         'mean.PantT_5', 'grad.PantT_5', 'sd.PantT_5', 'mean.PantT_15', 'grad.PantT_15', 'sd.PantT_15', 'mean.PantT_60','grad.PantT_60', 'sd.PantT_60', 
                         'mean.act_5', 'grad.act_5', 'sd.act_5','mean.act_15', 'grad.act_15', 'sd.act_15', 'mean.act_60', 'grad.act_60', 'sd.act_60'])

df_occ4_phy = df_occ4.filter(['mean.hr_5', 'grad.hr_5', 'sd.hr_5', 'mean.hr_15', 'grad.hr_15','sd.hr_15', 'mean.hr_60', 'grad.hr_60', 'sd.hr_60', 
                         'mean.WristT_5', 'grad.WristT_5', 'sd.WristT_5', 'mean.WristT_15', 'grad.WristT_15', 'sd.WristT_15', 'mean.WristT_60', 'grad.WristT_60', 'sd.WristT_60',
                         'mean.AnkleT_5', 'grad.AnkleT_5', 'sd.AnkleT_5', 'mean.AnkleT_15', 'grad.AnkleT_15', 'sd.AnkleT_15', 'mean.AnkleT_60', 'grad.AnkleT_60','sd.AnkleT_60', 
                         'mean.PantT_5', 'grad.PantT_5', 'sd.PantT_5', 'mean.PantT_15', 'grad.PantT_15', 'sd.PantT_15', 'mean.PantT_60','grad.PantT_60', 'sd.PantT_60', 
                         'mean.act_5', 'grad.act_5', 'sd.act_5','mean.act_15', 'grad.act_15', 'sd.act_15', 'mean.act_60', 'grad.act_60', 'sd.act_60'])

df_occ5_phy = df_occ5.filter(['mean.hr_5', 'grad.hr_5', 'sd.hr_5', 'mean.hr_15', 'grad.hr_15','sd.hr_15', 'mean.hr_60', 'grad.hr_60', 'sd.hr_60', 
                         'mean.WristT_5', 'grad.WristT_5', 'sd.WristT_5', 'mean.WristT_15', 'grad.WristT_15', 'sd.WristT_15', 'mean.WristT_60', 'grad.WristT_60', 'sd.WristT_60',
                         'mean.AnkleT_5', 'grad.AnkleT_5', 'sd.AnkleT_5', 'mean.AnkleT_15', 'grad.AnkleT_15', 'sd.AnkleT_15', 'mean.AnkleT_60', 'grad.AnkleT_60','sd.AnkleT_60', 
                         'mean.PantT_5', 'grad.PantT_5', 'sd.PantT_5', 'mean.PantT_15', 'grad.PantT_15', 'sd.PantT_15', 'mean.PantT_60','grad.PantT_60', 'sd.PantT_60', 
                         'mean.act_5', 'grad.act_5', 'sd.act_5','mean.act_15', 'grad.act_15', 'sd.act_15', 'mean.act_60', 'grad.act_60', 'sd.act_60'])

df_occ6_phy = df_occ6.filter(['mean.hr_5', 'grad.hr_5', 'sd.hr_5', 'mean.hr_15', 'grad.hr_15','sd.hr_15', 'mean.hr_60', 'grad.hr_60', 'sd.hr_60', 
                         'mean.WristT_5', 'grad.WristT_5', 'sd.WristT_5', 'mean.WristT_15', 'grad.WristT_15', 'sd.WristT_15', 'mean.WristT_60', 'grad.WristT_60', 'sd.WristT_60',
                         'mean.AnkleT_5', 'grad.AnkleT_5', 'sd.AnkleT_5', 'mean.AnkleT_15', 'grad.AnkleT_15', 'sd.AnkleT_15', 'mean.AnkleT_60', 'grad.AnkleT_60','sd.AnkleT_60', 
                         'mean.PantT_5', 'grad.PantT_5', 'sd.PantT_5', 'mean.PantT_15', 'grad.PantT_15', 'sd.PantT_15', 'mean.PantT_60','grad.PantT_60', 'sd.PantT_60', 
                         'mean.act_5', 'grad.act_5', 'sd.act_5','mean.act_15', 'grad.act_15', 'sd.act_15', 'mean.act_60', 'grad.act_60', 'sd.act_60'])

df_occ7_phy = df_occ7.filter(['mean.hr_5', 'grad.hr_5', 'sd.hr_5', 'mean.hr_15', 'grad.hr_15','sd.hr_15', 'mean.hr_60', 'grad.hr_60', 'sd.hr_60', 
                         'mean.WristT_5', 'grad.WristT_5', 'sd.WristT_5', 'mean.WristT_15', 'grad.WristT_15', 'sd.WristT_15', 'mean.WristT_60', 'grad.WristT_60', 'sd.WristT_60',
                         'mean.AnkleT_5', 'grad.AnkleT_5', 'sd.AnkleT_5', 'mean.AnkleT_15', 'grad.AnkleT_15', 'sd.AnkleT_15', 'mean.AnkleT_60', 'grad.AnkleT_60','sd.AnkleT_60', 
                         'mean.PantT_5', 'grad.PantT_5', 'sd.PantT_5', 'mean.PantT_15', 'grad.PantT_15', 'sd.PantT_15', 'mean.PantT_60','grad.PantT_60', 'sd.PantT_60', 
                         'mean.act_5', 'grad.act_5', 'sd.act_5','mean.act_15', 'grad.act_15', 'sd.act_15', 'mean.act_60', 'grad.act_60', 'sd.act_60'])

df_occ8_phy = df_occ8.filter(['mean.hr_5', 'grad.hr_5', 'sd.hr_5', 'mean.hr_15', 'grad.hr_15','sd.hr_15', 'mean.hr_60', 'grad.hr_60', 'sd.hr_60', 
                         'mean.WristT_5', 'grad.WristT_5', 'sd.WristT_5', 'mean.WristT_15', 'grad.WristT_15', 'sd.WristT_15', 'mean.WristT_60', 'grad.WristT_60', 'sd.WristT_60',
                         'mean.AnkleT_5', 'grad.AnkleT_5', 'sd.AnkleT_5', 'mean.AnkleT_15', 'grad.AnkleT_15', 'sd.AnkleT_15', 'mean.AnkleT_60', 'grad.AnkleT_60','sd.AnkleT_60', 
                         'mean.PantT_5', 'grad.PantT_5', 'sd.PantT_5', 'mean.PantT_15', 'grad.PantT_15', 'sd.PantT_15', 'mean.PantT_60','grad.PantT_60', 'sd.PantT_60', 
                         'mean.act_5', 'grad.act_5', 'sd.act_5','mean.act_15', 'grad.act_15', 'sd.act_15', 'mean.act_60', 'grad.act_60', 'sd.act_60'])

df_occ9_phy = df_occ9.filter(['mean.hr_5', 'grad.hr_5', 'sd.hr_5', 'mean.hr_15', 'grad.hr_15','sd.hr_15', 'mean.hr_60', 'grad.hr_60', 'sd.hr_60', 
                         'mean.WristT_5', 'grad.WristT_5', 'sd.WristT_5', 'mean.WristT_15', 'grad.WristT_15', 'sd.WristT_15', 'mean.WristT_60', 'grad.WristT_60', 'sd.WristT_60',
                         'mean.AnkleT_5', 'grad.AnkleT_5', 'sd.AnkleT_5', 'mean.AnkleT_15', 'grad.AnkleT_15', 'sd.AnkleT_15', 'mean.AnkleT_60', 'grad.AnkleT_60','sd.AnkleT_60', 
                         'mean.PantT_5', 'grad.PantT_5', 'sd.PantT_5', 'mean.PantT_15', 'grad.PantT_15', 'sd.PantT_15', 'mean.PantT_60','grad.PantT_60', 'sd.PantT_60', 
                         'mean.act_5', 'grad.act_5', 'sd.act_5','mean.act_15', 'grad.act_15', 'sd.act_15', 'mean.act_60', 'grad.act_60', 'sd.act_60'])

df_occ10_phy = df_occ10.filter(['mean.hr_5', 'grad.hr_5', 'sd.hr_5', 'mean.hr_15', 'grad.hr_15','sd.hr_15', 'mean.hr_60', 'grad.hr_60', 'sd.hr_60', 
                          'mean.WristT_5', 'grad.WristT_5', 'sd.WristT_5', 'mean.WristT_15', 'grad.WristT_15', 'sd.WristT_15', 'mean.WristT_60', 'grad.WristT_60', 'sd.WristT_60',
                          'mean.AnkleT_5', 'grad.AnkleT_5', 'sd.AnkleT_5', 'mean.AnkleT_15', 'grad.AnkleT_15', 'sd.AnkleT_15', 'mean.AnkleT_60', 'grad.AnkleT_60','sd.AnkleT_60', 
                          'mean.PantT_5', 'grad.PantT_5', 'sd.PantT_5', 'mean.PantT_15', 'grad.PantT_15', 'sd.PantT_15', 'mean.PantT_60','grad.PantT_60', 'sd.PantT_60', 
                          'mean.act_5', 'grad.act_5', 'sd.act_5','mean.act_15', 'grad.act_15', 'sd.act_15', 'mean.act_60', 'grad.act_60', 'sd.act_60'])

df_occ11_phy = df_occ11.filter(['mean.hr_5', 'grad.hr_5', 'sd.hr_5', 'mean.hr_15', 'grad.hr_15','sd.hr_15', 'mean.hr_60', 'grad.hr_60', 'sd.hr_60', 
                          'mean.WristT_5', 'grad.WristT_5', 'sd.WristT_5', 'mean.WristT_15', 'grad.WristT_15', 'sd.WristT_15', 'mean.WristT_60', 'grad.WristT_60', 'sd.WristT_60',
                          'mean.AnkleT_5', 'grad.AnkleT_5', 'sd.AnkleT_5', 'mean.AnkleT_15', 'grad.AnkleT_15', 'sd.AnkleT_15', 'mean.AnkleT_60', 'grad.AnkleT_60','sd.AnkleT_60', 
                          'mean.PantT_5', 'grad.PantT_5', 'sd.PantT_5', 'mean.PantT_15', 'grad.PantT_15', 'sd.PantT_15', 'mean.PantT_60','grad.PantT_60', 'sd.PantT_60', 
                          'mean.act_5', 'grad.act_5', 'sd.act_5','mean.act_15', 'grad.act_15', 'sd.act_15', 'mean.act_60', 'grad.act_60', 'sd.act_60'])

df_occ12_phy = df_occ12.filter(['mean.hr_5', 'grad.hr_5', 'sd.hr_5', 'mean.hr_15', 'grad.hr_15','sd.hr_15', 'mean.hr_60', 'grad.hr_60', 'sd.hr_60', 
                          'mean.WristT_5', 'grad.WristT_5', 'sd.WristT_5', 'mean.WristT_15', 'grad.WristT_15', 'sd.WristT_15', 'mean.WristT_60', 'grad.WristT_60', 'sd.WristT_60',
                          'mean.AnkleT_5', 'grad.AnkleT_5', 'sd.AnkleT_5', 'mean.AnkleT_15', 'grad.AnkleT_15', 'sd.AnkleT_15', 'mean.AnkleT_60', 'grad.AnkleT_60','sd.AnkleT_60', 
                          'mean.PantT_5', 'grad.PantT_5', 'sd.PantT_5', 'mean.PantT_15', 'grad.PantT_15', 'sd.PantT_15', 'mean.PantT_60','grad.PantT_60', 'sd.PantT_60', 
                          'mean.act_5', 'grad.act_5', 'sd.act_5','mean.act_15', 'grad.act_15', 'sd.act_15', 'mean.act_60', 'grad.act_60', 'sd.act_60'])

df_occ13_phy = df_occ13.filter(['mean.hr_5', 'grad.hr_5', 'sd.hr_5', 'mean.hr_15', 'grad.hr_15','sd.hr_15', 'mean.hr_60', 'grad.hr_60', 'sd.hr_60', 
                          'mean.WristT_5', 'grad.WristT_5', 'sd.WristT_5', 'mean.WristT_15', 'grad.WristT_15', 'sd.WristT_15', 'mean.WristT_60', 'grad.WristT_60', 'sd.WristT_60',
                          'mean.AnkleT_5', 'grad.AnkleT_5', 'sd.AnkleT_5', 'mean.AnkleT_15', 'grad.AnkleT_15', 'sd.AnkleT_15', 'mean.AnkleT_60', 'grad.AnkleT_60','sd.AnkleT_60', 
                          'mean.PantT_5', 'grad.PantT_5', 'sd.PantT_5', 'mean.PantT_15', 'grad.PantT_15', 'sd.PantT_15', 'mean.PantT_60','grad.PantT_60', 'sd.PantT_60', 
                          'mean.act_5', 'grad.act_5', 'sd.act_5','mean.act_15', 'grad.act_15', 'sd.act_15', 'mean.act_60', 'grad.act_60', 'sd.act_60'])

df_occ14_phy = df_occ14.filter(['mean.hr_5', 'grad.hr_5', 'sd.hr_5', 'mean.hr_15', 'grad.hr_15','sd.hr_15', 'mean.hr_60', 'grad.hr_60', 'sd.hr_60', 
                          'mean.WristT_5', 'grad.WristT_5', 'sd.WristT_5', 'mean.WristT_15', 'grad.WristT_15', 'sd.WristT_15', 'mean.WristT_60', 'grad.WristT_60', 'sd.WristT_60',
                          'mean.AnkleT_5', 'grad.AnkleT_5', 'sd.AnkleT_5', 'mean.AnkleT_15', 'grad.AnkleT_15', 'sd.AnkleT_15', 'mean.AnkleT_60', 'grad.AnkleT_60','sd.AnkleT_60', 
                          'mean.PantT_5', 'grad.PantT_5', 'sd.PantT_5', 'mean.PantT_15', 'grad.PantT_15', 'sd.PantT_15', 'mean.PantT_60','grad.PantT_60', 'sd.PantT_60', 
                          'mean.act_5', 'grad.act_5', 'sd.act_5','mean.act_15', 'grad.act_15', 'sd.act_15', 'mean.act_60', 'grad.act_60', 'sd.act_60'])
